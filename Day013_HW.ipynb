# %% [markdown]
# # PTT 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 印出最新文章的「作者」「標題」「時間」
# * ② 印出第一頁所有文章的「作者」「標題」「時間」

# %% [markdown]
# ### ① 印出最新文章的「作者」「標題」「時間」

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/NBA/index.html'
r = requests.get(url)

soup = BeautifulSoup(r.text, "html5lib")
# print(r.text)
df = pd.DataFrame(columns=['作者', '標題','時間'])
i=0
for d in soup.find_all(class_="title"):
    try:
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
        data=r.find_all(class_='article-meta-value')
        df.loc[i] = [data[0].text, data[2].text, data[3].text]
        i+=1
    except:
        continue
    
df.iloc[0]
# Out:
# 作者           NSYSUheng (Madara)
# 標題    [情報] AD今天29投20中，狂砍賽季新高50分
# 時間     Mon Dec  9 13:06:54 2019
# Name: 0, dtype: object

# %% [markdown]
# ### ② 印出第一頁所有文章的「作者」「標題」「時間」

# %%
df
# Out:
#                             作者                                      標題  \
# 0           NSYSUheng (Madara)               [情報] AD今天29投20中，狂砍賽季新高50分
# 1      cute320518 (cute320518)                [新聞] 向吉喆默哀 中國球迷素質讓林書豪動怒了
# 2            thnlkj0665 (灰色地帶)              [花邊] 笑稱跳投不如兒子 詹皇:我在家中只能排第三
# 3             MayBeSoft (小小瑜兒)         [花邊] Vogel: AD的表現是old-school風格的
# 4            LinBaoYan (負酬者聯盟)                [新聞] 戴維斯狂飆50分 湖人退灰狼笑納4連勝
# 5              Angel0724 (ND5)               [新聞] 致勝上籃後沒跟KD擊掌 丁丁：真不好意思
# 6               pneumo (超☆冒險蓋)                [情報] CP3對於OKC上半場兩次延誤比賽被吹
# 7          VeryGoodBoy (很棒的男孩)                     [情報] ESPN:湖人三頭怪沒人可擋
# 8            ColeNorris (Cole)                 [花邊] LBJ IG: 他們說我已無法再飛了
# 9            thnlkj0665 (灰色地帶)         [情報] Kyrie Irving 可能在下個星期參加球隊訓練
# 10           jk182325 (萬里花我老婆)                 [新聞] 稱哈登非最偉大火箭人　退役名將：除非
# 11              pneumo (超☆冒險蓋)                [外絮] Lowry在賽後跟騷擾者對嗆:來找我!
# 12               lovea (lovea)                 [花邊] 啦啦隊女郎列隊唱歌 壽星哈沃德享艷福
# 13            jack8587 (james)                [花邊] 中媒驚呼神劇本！ 林書豪完美詮釋沒有不
# 14      manuginobii (做愛校 果真累人)              [情報] 甜瓜談CP3被交易: 曾告訴他待在那要小心
# 15           forwardgo (高雄種馬柚)                     [討論] LBJ生涯搭配最強的隊友是誰
# 16          NSYSUheng (Madara)              [討論] 歷史上的今天 CP3被交易到湖人被聯盟否決
# 17           fukawa947 (交大薛之謙)                  [新聞] 僅次柯比！一眉哥爆砍50分歸功詹皇
# 18                  Vedan (味丹)                      [公告] 樂透取消及未來不再開啟樂透
# 19  qazwsx879345 (Rajon Rondo)                           [公告] 版主上任相關事項
# 20              JerroLi (銀色小刀)  [情報] SEASON Schedule 賽程 December 19–20
# 21         dragon803 (好想去露營啊~)          [公告]是否禁止basketball top 5文章投票開始
#
#                           時間
# 0   Mon Dec  9 13:06:54 2019
# 1   Mon Dec  9 13:35:38 2019
# 2   Mon Dec  9 13:52:22 2019
# 3   Mon Dec  9 14:00:54 2019
# 4   Mon Dec  9 14:02:29 2019
# 5   Mon Dec  9 14:43:34 2019
# 6   Mon Dec  9 15:39:12 2019
# 7   Mon Dec  9 16:07:58 2019
# 8   Mon Dec  9 16:11:53 2019
# 9   Mon Dec  9 16:12:26 2019
# 10  Mon Dec  9 16:56:21 2019
# 11  Mon Dec  9 17:15:15 2019
# 12  Mon Dec  9 17:19:58 2019
# 13  Mon Dec  9 18:00:20 2019
# 14  Mon Dec  9 18:09:50 2019
# 15  Mon Dec  9 19:37:37 2019
# 16  Mon Dec  9 19:50:17 2019
# 17  Mon Dec  9 20:05:54 2019
# 18  Mon Jun 24 15:08:02 2019
# 19  Fri Oct 25 10:44:03 2019
# 20  Fri Nov 29 00:46:01 2019
# 21  Sun Dec  8 23:55:00 2019

# %% [markdown]
# ### ③ 試著爬爬看其他版的文章

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/Stock/index.html'
r = requests.get(url)
# for some boards, we need to add cookies...  r = requests.get(url, cookies={'over18': '1'})

soup = BeautifulSoup(r.text, "html5lib")
# print(r.text)
df = pd.DataFrame(columns=['作者', '標題','時間'])
i=0
for d in soup.find_all(class_="title"):
    try:
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
        data=r.find_all(class_='article-meta-value')
        df.loc[i] = [data[0].text, data[2].text, data[3].text]
        i+=1
    except:
        continue
    
df
# Out:
#                           作者                             標題  \
# 0   mayingnine (個性決定能否投資賺大錢)     [新聞] 【公告】群創光電2019年11月自結合併營
# 1            PTTISDOG (帥氣阿寶)   Re: [新聞] 反擊美國！中國下令公家機關3年內換掉外
# 2             light1023 (嚕嚕)           [新聞] 台新金108年11月份自結損益
# 3         spirit119 (一二三木頭人)       [新聞] 大聯大「收購案」文曄案 遭疑是炒作、意
# 4        zesonpso (幹 正義的孩子王)                  Re: [心得] 和潤進場
# 5            zxcvxx (zxcvxx)  [新聞] 高通企圖以5G＋Snapdragon平台戰略搶奪
# 6         ESunBoy (嘉偉老師大獲全勝)  [新聞] 【5880 合庫金】108年11月份自結合併盈餘
# 7         ESunBoy (嘉偉老師大獲全勝)  [新聞] 【2891 中信金】108年11月份自結合併盈餘
# 8            gongling (nikt)   Re: [新聞] 反擊美國！中國下令公家機關3年內換掉外
# 9              IanLi (IanLi)                  [公告] 精華區導覽Q&A
# 10        housemance (鎬鍶鏝矽銥)           [閒聊] 2019/12/09 盤後閒聊
#
#                           時間
# 0   Mon Dec  9 16:09:19 2019
# 1   Mon Dec  9 16:41:59 2019
# 2   Mon Dec  9 17:47:34 2019
# 3   Mon Dec  9 18:02:08 2019
# 4   Mon Dec  9 18:06:39 2019
# 5   Mon Dec  9 18:14:19 2019
# 6   Mon Dec  9 18:28:38 2019
# 7   Mon Dec  9 18:56:26 2019
# 8   Mon Dec  9 19:46:27 2019
# 9   Sun Jan 25 23:18:20 2015
# 10  Mon Dec  9 14:05:55 2019
